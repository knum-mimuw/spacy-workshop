# %%
import spacy
import pandas as pd

# %%
df=pd.read_csv('the_guardian_articles.csv', nrows=100)

# %%
df.head()
# Out:
#                                                 text         author
# 0  Federal investigators are examining the first ...      Dan Tynan
# 1  Apple is reportedly considering a potential ta...            NaN
# 2  From turning your photos into gifs to riding b...  Stuart Dredge
# 3                         It’s Friday – what a week!            NaN
# 4  V\nideo games are often criticised for their o...   Keith Stuart

# %%
nlp=spacy.load('en')

# %%
df['doc']=df.text.apply(lambda x: nlp(x))

# %%
length = df['doc'].apply(len)

# %%
df['len']=length

# %%
df.len.describe()
# Out:
# count     100.000000
# mean      859.190000
# std       412.826613
# min         3.000000
# 25%       517.750000
# 50%       844.000000
# 75%      1087.500000
# max      2172.000000
# Name: len, dtype: float64

# %%
df[df['len']<50]
# Out:
#                           text author                                    doc  \
# 3   It’s Friday – what a week!    NaN  (It, ’s, Friday, –, what, a, week, !)
# 61        Chatterbox: Thursday    NaN              (Chatterbox, :, Thursday)
#
#     len
# 3     8
# 61    3

# %%
df['ents']=df['doc'].apply(lambda doc: doc.ents)

# %%
df['ents']

# %%
doc=df['doc'].iloc[0]

# %%
[ent.label_ for ent in doc.ents]
# Out:
# ['ORDINAL',
#  'PRODUCT',
#  'PERSON',
#  'CARDINAL',
#  'GPE',
#  'PRODUCT',
#  'DATE',
#  'ORG',
#  'GPE',
#  'PERSON',
#  'PERSON',
#  'PERSON',
#  'PRODUCT',
#  'ORG',
#  'DATE',
#  'PRODUCT',
#  'ORG',
#  'PRODUCT',
#  'PRODUCT',
#  'PERSON',
#  'DATE',
#  'PERSON',
#  'GPE',
#  'PERSON',
#  'CARDINAL',
#  'PRODUCT',
#  'QUANTITY',
#  'QUANTITY',
#  'ORG',
#  'PERSON',
#  'DATE',
#  'PRODUCT',
#  'DATE',
#  'PERSON',
#  'ORG',
#  'PERSON',
#  'DATE',
#  'PRODUCT']

# %%
all_ents=[ent for ents in df['ents'] for ent in ents]

# %%
for ent in all_ents:
    ent.merge()

# %%
{ent.label_ for ent in all_ents}
# Out:
# {'CARDINAL',
#  'DATE',
#  'EVENT',
#  'FAC',
#  'GPE',
#  'LANGUAGE',
#  'LAW',
#  'LOC',
#  'MONEY',
#  'NORP',
#  'ORDINAL',
#  'ORG',
#  'PERCENT',
#  'PERSON',
#  'PRODUCT',
#  'QUANTITY',
#  'TIME',
#  'WORK_OF_ART'}

# %%
labels_freq={label: 0 for label in {ent.label_ for ent in all_ents}}

# %%
for ent in all_ents:
    labels_freq[ent.label_]+=1

# %%
labels_freq
# Out:
# {'CARDINAL': 448,
#  'DATE': 676,
#  'EVENT': 14,
#  'FAC': 83,
#  'GPE': 750,
#  'LANGUAGE': 6,
#  'LAW': 10,
#  'LOC': 62,
#  'MONEY': 132,
#  'NORP': 148,
#  'ORDINAL': 138,
#  'ORG': 1241,
#  'PERCENT': 58,
#  'PERSON': 947,
#  'PRODUCT': 190,
#  'QUANTITY': 52,
#  'TIME': 57,
#  'WORK_OF_ART': 50}

# %%
all_persons=[ent for ent in all_ents if ent.label_=='PERSON']

# %%
[person.sent for person in all_persons if 'Trump' in person.text]
# Out:
# [That complacency has been shattered by the revolt of marginalised citizens around the world, angry at “elite” failings and looking to the likes of Donald Trump.,
#  When Mark Zuckerberg was asked by his own employees if they should act to prevent certain Donald Trump stories gaining traction his answer was absolutely not.]

# %%
all_art=[ent.text for ent in all_ents if ent.label_=='WORK_OF_ART']

# %%
set(all_art)
# Out:
# {'Android 1.5 –',
#  'Ansip and Jourova',
#  'Brought',
#  'Corporations Can Make Doing Good an Integral',
#  'Encrypting Your Laptop',
#  'Film Now',
#  'Future Shock',
#  'Game Boy',
#  'Get Windows 10',
#  'Guitar Archive',
#  'Harry Potter DVD',
#  'Marvel’s Iron Man',
#  'Most Corrupt Candidate',
#  'Musk told Fortune.\n\n',
#  'Nobel',
#  'Paid for by”',
#  'Playboy',
#  'Pokémon',
#  'Pokémon Go',
#  'Queers Hate Techies',
#  'Radar',
#  'Scaling at GitHub’ - with a large portion of the problem being the',
#  'Space Pavilion',
#  'Star Wars',
#  'The Associated Press',
#  'The Center',
#  'The Dyson Demo',
#  'The Infinite Monkey Cage',
#  'The Managed Heart',
#  'The Secret Tesla Motors Master Plan',
#  'The “My Eyes Only”',
#  'The “Sorry',
#  'They Live',
#  'Totem Adornments',
#  'Wi-Fried',
#  'Your Autopilot Has Arrived',
#  'a Tesla Model S',
#  'the Gold Coast',
#  'the Guinness Book of Records',
#  'the Live from Jodrell Bank',
#  'the Play Store',
#  '“Gotta Catch ‘Em All!',
#  '“Killing it',
#  '“Light Detection and Ranging”',
#  '“See More Settings',
#  '“Train',
#  '“Upgrade now”',
#  '”\n\n',
#  '” Adam Summers'}

# %%
def ent_filter(ents, kind):
    return [ent for ent in ents if ent.label_==kind]

# %%
df['persons']=df['ents'].apply(lambda ents: ent_filter(ents, 'PERSON'))

# %%
df.head()
# Out:
#                                                 text         author  \
# 0  Federal investigators are examining the first ...      Dan Tynan
# 1  Apple is reportedly considering a potential ta...            NaN
# 2  From turning your photos into gifs to riding b...  Stuart Dredge
# 3                         It’s Friday – what a week!            NaN
# 4  V\nideo games are often criticised for their o...   Keith Stuart
#
#                                                  doc   len  \
# 0  (Federal, investigators, are, examining, the, ...   445
# 1  (Apple, is, reportedly, considering, a, potent...   300
# 2  (From, turning, your, photos, into, gifs, to, ...  1511
# 3               (It, ’s, Friday, –, what, a week, !)     8
# 4  (V, \n, ideo, games, are, often, criticised, f...   775
#
#                                                 ents  sentiment  \
# 0  ((first), (Tesla), (Joshua Brown), (40-year), ...  -0.047798
# 1  ((Apple), (Jay Z’s), (Tidal), (Tidal), (Kanye ...   0.128217
# 2  ((this month), (IAP), (Android), (monthly), (t...   0.196480
# 3                               ((Friday), (a week))   0.000000
# 4  ((British), (this week), (last minute), (Ubiso...   0.085346
#
#                                              persons
# 0  [(Joshua Brown), (Brown), (Tesla), (Brown), (E...
# 1  [(Jay Z’s), (Tidal), (Tidal), (Kanye West), (M...
# 2  [(Toca Boca), (Netflix), (Rodeo Stampede), (Ka...
# 3                                                 []
# 4  [(Borgias), (Creed II), (Machiavelli), (Sid Me...

# %%
from textblob.sentiments import PatternAnalyzer

# %%
analyzer=PatternAnalyzer()

# %%
analyzer.analyze(doc.text).polarity
# Out:
# -0.04779785431959346

# %%
doc.sentiment=analyzer.analyze(doc.text).polarity

# %%
doc.sentiment
# Out:
# -0.17277777194976807

# %%
for doc in df['doc']:
    doc.sentiment=analyzer.analyze(doc.text).polarity

# %%
df['sentiment']=df['doc'].apply(lambda d: d.sentiment)

# %%
df.head()
# Out:
#                                                 text         author  \
# 0  Federal investigators are examining the first ...      Dan Tynan
# 1  Apple is reportedly considering a potential ta...            NaN
# 2  From turning your photos into gifs to riding b...  Stuart Dredge
# 3                         It’s Friday – what a week!            NaN
# 4  V\nideo games are often criticised for their o...   Keith Stuart
#
#                                                  doc   len  \
# 0  (Federal, investigators, are, examining, the, ...   445
# 1  (Apple, is, reportedly, considering, a, potent...   300
# 2  (From, turning, your, photos, into, gifs, to, ...  1511
# 3               (It, ’s, Friday, –, what, a week, !)     8
# 4  (V, \n, ideo, games, are, often, criticised, f...   775
#
#                                                 ents  sentiment  \
# 0  ((first), (Tesla), (Joshua Brown), (40-year), ...  -0.047798
# 1  ((Apple), (Jay Z’s), (Tidal), (Tidal), (Kanye ...   0.128217
# 2  ((this month), (IAP), (Android), (monthly), (t...   0.196480
# 3                               ((Friday), (a week))   0.000000
# 4  ((British), (this week), (last minute), (Ubiso...   0.085346
#
#                                              persons
# 0  [(Joshua Brown), (Brown), (Tesla), (Brown), (E...
# 1  [(Jay Z’s), (Tidal), (Tidal), (Kanye West), (M...
# 2  [(Toca Boca), (Netflix), (Rodeo Stampede), (Ka...
# 3                                                 []
# 4  [(Borgias), (Creed II), (Machiavelli), (Sid Me...

# %%
jay=df['persons'][1][0]

# %%
jay_token=df['persons'][1][0][0]

# %%
similarities=[]
for i, person in enumerate(all_persons):
    similarities.append((person, jay_token.similarity(person[0])))

# %%
sorted(similarities,key= lambda x: x[1], reverse=True)

#Słabo działa, spróbujemy z większymi wektorami
# Out:
# [(Jay Z’s, 1.0),
#  (Jay Z’s, 1.0),
#  (Joshua Brown, 0.76865244),
#  (Hillary Clinton, 0.75971967),
#  (Mark Twain, 0.7441862),
#  (Banks, 0.7419728),
#  (John Lewis, 0.7366898),
#  (Joshua Brown, 0.7233147),
#  (Taylor Swift, 0.7210378),
#  (Avid Life’s, 0.71220845),
#  (Jonathan Ross’s, 0.6951377),
#  (Harry Potter, 0.6825176),
#  (Madonna, 0.6817763),
#  (Levy, 0.67637736),
#  (Joshua Brown, 0.6725146),
#  (Charles, 0.6723214),
#  (Alvin Toffler, 0.66949624),
#  (Creed II, 0.66866565),
#  (Rob Segal, 0.6670843),
#  (Harmony Korine, 0.6658535),
#  (Aiden Byrne, 0.65130115),
#  (Alex Gibney, 0.65062433),
#  (Gibney, 0.64995867),
#  (Sebastien Missoffe, 0.64696395),
#  (Trak, 0.64406985),
#  (Tim Cook, 0.63841516),
#  (Tim Cook, 0.6363678),
#  (Ray Lakeland, 0.63124907),
#  (Toffler, 0.62472504),
#  (Arthur Conan Doyle, 0.6245247),
#  (Eddie Waring, 0.6232251),
#  (Ukip, 0.6231637),
#  (Nunn, -0.00776314),
#  (Coherence Tomography, -0.0079404935),
#  (Take Chris Martin, -0.007955658),
#  (Brown, -0.007974308),
#  (Barrett, -0.008410172),
#  (Gordon Brown, -0.008507686),
#  (Musk’s, -0.0088833105),
#  (Windows, -0.009130752),
#  (Karen Levy, -0.009149544),
#  (Blackberry, -0.009479133),
#  (Frank Baressi, -0.01085687),
#  (Moon, -0.011668024),
#  (Jobs, -0.012170698),
#  (Fi Plus, -0.012221197),
#  (Linus Torvalds, -0.012447456),
#  (Brandt, -0.012784888),
#  (Wiley, -0.0136138555),
#  (Buzzbike, -0.0138224345),
#  (Diego Gigliani, -0.014022974),
#  (Privacy Shield, -0.014854002),
#  (Wallace, -0.015593167),
#  (Ragunathan Rajkumar, -0.015935825),
#  (Christopher Nolan, -0.016347203),
#  (Denzel Smith, -0.016350588),
#  (Alan Garner, -0.016486943),
#  (Zoe “Zoella” Sugg, -0.016808767),
#  (Tesla, -0.016939227),
#  (Autopilot, -0.016942829),
#  (Madonna, -0.017143533),
#  (Sherlock Holmes, -0.017534805),
#  (Tidal, -0.017586136),
#  (Autopilot, -0.01789143),
#  (Hyperloop, -0.018277662),
#  (Toffler, -0.018708432),
#  (Jimmy Iovine, -0.020018822),
#  (Gawker, -0.020277284),
#  (Isis, -0.020388523),
#  (Wi-Fried, -0.020513503),
#  (Hugo Chávez, -0.020696107),
#  (Tesla, -0.02075311),
#  (Autopilot, -0.020812288),
#  (Balderton Capital, -0.021087606),
#  (Lidar, -0.021144023),
#  (Ian Morris, -0.021558017),
#  (PokéCoins, -0.02176469),
#  (Trak, -0.022049969),
#  (Tidal, -0.02248623),
#  (Check Point, -0.022507105),
#  (Gibney, -0.022693753),
#  (Elon Musk, -0.02283198),
#  (Samuel Ely, -0.02296951),
#  (Michael Bautista, -0.02331907),
#  (Stanley Kubrick, -0.023348518),
#  (Jelly Bean, -0.023395268),
#  (Tesla, -0.024848916),
#  (Sam, -0.025019005),
#  (AI, -0.025723334),
#  (Max Conze, -0.025909675),
#  (Cassie, -0.026666302),
#  (Jay Z, -0.0267579),
#  (PS4, -0.026791811),
#  (
#
#   submitGit, -0.026889877),
#  (Jeremy Corbyn, -0.02715182),
#  (Hares, -0.027475227),
#  (Bitcoin, -0.0275024),
#  (Kanye West, -0.028988063),
#  (Dave, -0.02925215),
#  (Ray, -0.029992582),
#  (Respawn, -0.030246008),
#  (Respawn, -0.030477213),
#  (Greenpeace, -0.03142733),
#  (
#
#   Levy, -0.032063883),
#  (Selfie, -0.03273238),
#  (Blair, -0.0330893),
#  (Wolverhampton, -0.033255365),
#  (Billed, -0.033297595),
#  (Jade Davis, -0.03360071),
#  (Ramesh Kakade, -0.033842027),
#  (Naidenov, -0.034116462),
#  (Burton, -0.03462058),
#  (Bounty Hunt, -0.034702383),
#  (Wi-Fi, -0.03508856),
#  (Meerkat, -0.03554143),
#  (
#
#   Smith, -0.035935096),
#  (Andy, -0.03637739),
#  (Brian Eno, -0.036722064),
#  (Tidal, -0.03701331),
#  (Twitter, -0.03707066),
#  (Ed Lee, -0.038299523),
#  (Elena Gaytan, -0.038795527),
#  (David Willetts, -0.039407324),
#  (Jelly Bean, -0.041274678),
#  (Stuxnet, -0.041825403),
#  (Liz McInnes, -0.042043034),
#  (James Millership, -0.042622298),
#  (Amec Foster Wheeler, -0.042713664),
#  (Brown, -0.043542862),
#  (Respawn, -0.04418041),
#  (Jacques de la Bouillerie, -0.04433284),
#  (Ferdinand Dudenhöffer, -0.044521417),
#  (Robinson, -0.045215618),
#  (Lesley Xavier, -0.045481868),
#  (Amazon Fresh, -0.04548777),
#  (Mobiles, -0.04576403),
#  (Lidar, -0.04584719),
#  (Paddy Dickinson, -0.04585429),
#  (Lidar, -0.046734393),
#  (Bloomberg, -0.047617774),
#  (Kanye West, -0.048288792),
#  (Lemon, -0.04844299),
#  (Tesla, -0.049619377),
#  (Mark Zuckerberg, -0.04967669),
#  (Ashley Madison, -0.049857758),
#  (Musk, -0.05043149),
#  (Waiting, -0.050642405),
#  (Latino, -0.05145589),
#  (Twitter, -0.0517514),
#  (Lovell, -0.051915832),
#  (Rdio, -0.052917663),
#  (Johnson, -0.05309923),
#  (Policy Connect, -0.053302612),
#  (Ralph Pini, -0.05354809),
#  (Kings Place, -0.05514958),
#  (Alicia Keys, -0.05579641),
#  (Humanitas, -0.055949368),
#  (Ours, -0.056010235),
#  (Jenkins, -0.056813464),
#  (Jeff Bezos, -0.057464324),
#  (Wi-Fi, -0.057591088),
#  (Cocoa, -0.059226483),
#  (Alisher Usmanov, -0.06030831),
#  (Ed Miliband’s, -0.06090954),
#  (Trak, -0.061142024),
#  (Brogrammers, -0.06366879),
#  (David Lynch, -0.06377116),
#  (Theranos, -0.06440964),
#  (Gibney, -0.06476345),
#  (Jennifer Lawrence, -0.0647926),
#  (Kairosoft, -0.06559195),
#  (Trak, -0.06576121),
#  (Pearse Keane, -0.066005126),
#  (George Rzevski, -0.06652521),
#  (Brown, -0.06791727),
#  (Peter Alliss, -0.06792631),
#  (Alex Reid, -0.067934066),
#  (Edmonton, -0.06795446),
#  (Davison, -0.0679729),
#  (McCoy, -0.068184786),
#  (Ashley Madison, -0.06987858),
#  (Gove, -0.06995836),
#  (Hares, -0.07197907),
#  (Todd, -0.07247457),
#  (Deborah Lupton, -0.07278681),
#  (Dickinson, -0.07518285),
#  (Respawn, -0.076045044),
#  (Tidal, -0.07849611),
#  (Titanfall, -0.080582164),
#  (Tom Watson, -0.08200776),
#  (Android, -0.08257273),
#  (Musk, -0.08326527),
#  (Murdoch, -0.08426962),
#  (Ashley Madison, -0.085346796),
#  (Twitter, -0.08560645),
#  (Vera Jourova, -0.086816296),
#  (Carren Jao, -0.08702167),
#  (Raul Diaz, -0.08733453),
#  (Dave Mustaine, -0.08791269),
#  (Helen Keen, -0.0881646),
#  (Seidel, -0.08818601),
#  (Zuckerberg, -0.08965261),
#  (Carbine, -0.08980897),
#  (Taru Kapoor, -0.090177536),
#  (Uncle Pete, -0.09105382),
#  (vehicles’, -0.09413682),
#  (Brian Colello, -0.09430951),
#  (Self Portrait, -0.09447085),
#  (Mark Hughes, -0.09476917),
#  (Check Point, -0.09495681),
#  (Brian Cox, -0.09564071),
#  (Sandro, -0.098111376),
#  (Garrett, -0.09829361),
#  (Merlin, -0.098735854),
#  (Pranit Bauva, -0.104149275),
#  (Jonathan Caouette, -0.105196625),
#  (Twitter, -0.10616057),
#  (David Newby, -0.10723272),
#  (Forelli, -0.1080212),
#  (Lidar, -0.10859532),
#  (Andrew Fentem, -0.10976928),
#  (Cornelia Yzer, -0.11016309),
#  (Tidal, -0.11043357),
#  (Peasant Children, -0.111250035),
#  (Travis Todd, -0.111894146),
#  (Michelle Du-Prat, -0.11307976),
#  (Slavoj Zizek, -0.116698876),
#  (Panahi, -0.12170073),
#  (Bluedot, -0.12262855),
#  (Wiley, -0.12514026),
#  (Harry Briggs, -0.12515673),
#  (Stuxnet, -0.1263243),
#  (Miller, -0.12729967),
#  (Jay Z, -0.12736776),
#  (Damian Kimmelman, -0.13315944),
#  (Tim Peake, -0.13722974),
#  (Hovertrax, -0.1391795),
#  (Nebula, -0.14096387),
#  (Wendy Berliner, -0.14309822),
#  (Tidal, -0.14434704),
#  (Jay Z, -0.14542662),
#  (Alton Towers, -0.14788494),
#  (Ari Bloom, -0.15031445),
#  (Snap, -0.15479144),
#  (Yogita Suryavanshi, -0.15512192),
#  (Pidgey, -0.1582908),
#  (
#
#   Smartphone, -0.15966251),
#  (Borgias, -0.1625935),
#  (Jack, -0.17006944),
#  (William Oliver Healey, -0.17517976),
#  (Harbisson, -0.17961945),
#  (Toca Boca, -0.19228205),
#  (Kyra Kazantzis, -0.2022153),
#  (Tidal, -0.20813188),
#  (Jonathan Bernstein, -0.21280837),
#  (Ghost Train, -0.21948896),
#  (Neil Blumenthal, -0.22184233)]

# %%
scoring=[]
for doc in df['doc']:
    if('Jay Z' in doc.text):
        scoring.append(doc.sentiment)

# %%
scoring
# Out:
# [0.12821747362613678, 0.05493183061480522]

# %% [markdown]
# ## Setting extension to sentence level polarity

# %%
from spacy.tokens import Span

# %%
def polarity(span):
    return analyzer.analyze(span.text).polarity

# %%
Span.set_extension('polarity', getter=polarity)

# %%
for sent in doc.sents:
    print(sent._.polarity)
# Out:
# 0.04999999999999999
# 0.0
# 0.0
# -0.4
# 0.0
# -0.3499999999999999
# -0.35
# -0.2375
# -0.2333333333333333
# -0.11851851851851852
# 0.25
# 0.0
# 0.0

# %%
from textacy.lexicon_methods import emotional_valence

# %%
textacy.lexicon_methods.download_depechemood()

# %%
emotional_valence(doc)
# Out:
# defaultdict(float,
#             {'AFRAID': 0.13200744218749993,
#              'AMUSED': 0.14212075588202255,
#              'ANGRY': 0.1158086805909092,
#              'ANNOYED': 0.11762475423295463,
#              'DONT_CARE': 0.11652026924999999,
#              'HAPPY': 0.12144892282162159,
#              'INSPIRED': 0.1563725598432433,
#              'SAD': 0.12797938725543484})
